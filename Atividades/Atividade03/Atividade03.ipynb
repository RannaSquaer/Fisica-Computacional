# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def U(x):
    return (x**2)*(x-1)*(x+1)+(x/4)

# %%
def dU(x):
    return 4*(x**3)-2*x + (1/4)

# %%
def gradiente(dU, x0, alpha=0.1, eps=0.01, max=1000):
    x=x0
    lista = [x]
    for _ in range(max):
        x1=x-alpha*dU(x)
        lista.append(x1)
        if abs(x1-x)<eps:
            break
        x=x1
    return lista

# %%
#Gráfico potencial
eixo_x=np.linspace(-2.4, 2.4, 200)
eixo_y=U(eixo_x)

# %%
#Parâmetros do código
x0=1
alpha=0.6
eps=0.001
maximo=1000

#Calculando o gradiente 
caminho=gradiente(dU, x0, alpha, eps, maximo)

#Primeira Condição
plt.figure(figsize=(10, 6))
plt.plot(eixo_x, eixo_y, label='U(x) = x²(x-1)(x+1)+(x/4)')  # Plota a função
plt.plot(caminho, [U(x) for x in caminho], 'ro--', label='Trajetória da partícula')  # Trajetória
plt.xlabel('x')
plt.ylabel('U(x)')
plt.ylim(-1,1)
plt.title('Gradiente Descendente para U(x) = x²(x-1)(x+1)+(x/4)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Parâmetros do código
x0=1
alpha=0.03
eps=0.001
maximo=1000

#Calculando o gradiente 
caminho=gradiente(dU, x0, alpha, eps, maximo)

#Segunda Condição
plt.figure(figsize=(10, 6))
plt.plot(eixo_x, eixo_y, label='U(x) = x²(x-1)(x+1)+(x/4)')  # Plota a função
plt.plot(caminho, [U(x) for x in caminho], 'ro--', label='Trajetória da partícula')  # Trajetória
plt.xlabel('x')
plt.ylabel('U(x)')
plt.ylim(-1,1)
plt.title('Gradiente Descendente para U(x) = x²(x-1)(x+1)+(x/4)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# $\alpha$ é a taxa de aprendizado para encontrar o mínimo da função U(x), ao aumentá-lo é possível notar que o passo dado é espaçado e com isso a convergência acontece mais rápido, além disso  os pontos no gráfico não representam a forma de linha da curva investigada. Quando o $\alpha$ é
